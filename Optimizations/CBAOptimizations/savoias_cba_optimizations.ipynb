# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import spearmanr, linregress
import os
from datetime import datetime
import sys
sys.path.append('/home/wallacelab/complexity-final/Optimizations')

import optimization

# %%
# Parameters
num_simulations = 1  # Number of simulations to run
task_name = "complexity_prediction"
predictor_columns = ["Irregularity", "Disorganized", "Asymmetry", "Chaotic", "Randomness", 
                     "Variability", "Multicolored", "Heterogeneity", "Grainy", "Isotropy", 
                     "Cluttered", "Ambiguity", "Intricate"]
all_weights = []
spearman_rhos = []

# %%
# Run the simulation multiple times
for _ in range(num_simulations):
    # Load your data (ensure these paths are correct)
    df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_ad.csv')
    df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Advertisement/savoias_advertisement_cba_embedding.csv')
    
    # Run the bayesian optimization function (make sure it's defined in this notebook or imported)
    best_weights, best_rho = optimization.bayesian_optimization_fit(df1, df2, predictor_columns, task_name=task_name, cross_validate=False)
    all_weights.append(best_weights)
    spearman_rhos.append(best_rho)

# Find the best (highest) Spearman rho and corresponding weights
best_rho_index = np.argmax(spearman_rhos)
best_rho = spearman_rhos[best_rho_index]
best_weights = all_weights[best_rho_index]

# Calculate predictions for each image using the best weights
# Assuming `df2` contains predictor columns and `df1` contains the actual values
df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_ad.csv')
df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Advertisement/savoias_advertisement_cba_embedding.csv')

# Ensure that df1 and df2 are aligned by merging on 'image' column if necessary
if 'image' in df1.columns and 'image' in df2.columns:
    combined_df = pd.merge(df1, df2, on='image')
    y_true = combined_df['Normalized Average'].values
    X = combined_df[predictor_columns].values
else:
    y_true = df1['Normalized Average'].values
    X = df2[predictor_columns].values

# Get predicted values by multiplying X by best weights
y_pred = X @ best_weights

# Calculate the line of best fit for predicted vs. actual
slope, intercept, _, _, _ = linregress(y_pred, y_true)  # Predicted (x) vs. Actual (y)
line_x = np.linspace(y_pred.min(), y_pred.max(), 100)  # Restrict line_x to the range of predicted values
line_y = slope * line_x + intercept  # Compute corresponding y values using the regression equation

# Plot the scatter plot and line of best fit
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, y_true, label="Predicted vs. Actual")  # Predicted on x, Actual on y
plt.plot(line_x, line_y, color="red", label="Line of Best Fit")  # Best-fit line for predicted vs. actual
plt.xlabel("CLIP-CBA Complexity Score (Predicted)")
plt.ylabel("Normalized Participant Complexity Rating (Actual)")
plt.title(f"CLIP-CBA Optimization vs. Participant Ratings: Spearman Rho = {best_rho:.4f}")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Results will be saved in: ./optimization_results_20241120_164253
# Starting optimization without cross-validation...
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.019574770111852997
# Predictor Disorganized: Initial Spearman rho = -0.09387472817610071
# Predictor Asymmetry: Initial Spearman rho = -0.03718861245976088
# Predictor Chaotic: Initial Spearman rho = 0.24123387363835086
# Predictor Randomness: Initial Spearman rho = -0.00011252454651559552
# Predictor Variability: Initial Spearman rho = -0.016513352282985363
# Predictor Multicolored: Initial Spearman rho = 0.31073503487553017
# Predictor Heterogeneity: Initial Spearman rho = -0.07798326155352488
# Predictor Grainy: Initial Spearman rho = -0.18993018206367365
# Predictor Isotropy: Initial Spearman rho = 0.11379457356393485
# Predictor Cluttered: Initial Spearman rho = -0.20539855639135088
# Predictor Ambiguity: Initial Spearman rho = -0.17963418605749668
# Predictor Intricate: Initial Spearman rho = 0.3485830411778724
#
# Initial weights set to predictor Intricate with weight 1. Initial Spearman rho = 0.3485830411778724
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.4232010686269375
# Updated best overall rho to 0.4232010686269375
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.42193404223317194
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.4194705048281238
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.42130315460904116
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.42284324056901795
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.41996786332372277
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.42187177865076664
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.421501947974552
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.4171607509699804
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.4206242565117304
# Final weights saved to ./optimization_results_20241120_164253/final_weights_complexity_prediction.csv
#
# Optimization results:
# Irregularity: Weight = 0.0000
# Disorganized: Weight = 0.0148
# Asymmetry: Weight = 0.1178
# Chaotic: Weight = 0.2327
# Randomness: Weight = 0.0000
# Variability: Weight = 0.0340
# Multicolored: Weight = 0.2327
# Heterogeneity: Weight = 0.0000
# Grainy: Weight = 0.0326
# Isotropy: Weight = 0.1026
# Cluttered: Weight = 0.0000
# Ambiguity: Weight = 0.0000
# Intricate: Weight = 0.2327
# Best Spearman rho = 0.4232
# Final weights saved to ./optimization_results_20241120_164253/final_weights_complexity_prediction.csv

# %%
# Run the simulation multiple times
for _ in range(num_simulations):
    # Load your data (ensure these paths are correct)
    df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_art.csv')
    df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Art/savoias_art_cba_embedding.csv')
    
    # Run the bayesian optimization function (make sure it's defined in this notebook or imported)
    best_weights, best_rho = optimization.bayesian_optimization_fit(df1, df2, predictor_columns, task_name=task_name, cross_validate=True)
    all_weights.append(best_weights)
    spearman_rhos.append(best_rho)

# Find the best (highest) Spearman rho and corresponding weights
best_rho_index = np.argmax(spearman_rhos)
best_rho = spearman_rhos[best_rho_index]
best_weights = all_weights[best_rho_index]

# Calculate predictions for each image using the best weights
# Assuming `df2` contains predictor columns and `df1` contains the actual values
df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_art.csv')
df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Art/savoias_art_cba_embedding.csv')

# Ensure that df1 and df2 are aligned by merging on 'image' column if necessary
if 'image' in df1.columns and 'image' in df2.columns:
    combined_df = pd.merge(df1, df2, on='image')
    y_true = combined_df['Normalized Average'].values
    X = combined_df[predictor_columns].values
else:
    y_true = df1['Normalized Average'].values
    X = df2[predictor_columns].values

# Get predicted values by multiplying X by best weights
y_pred = X @ best_weights

# Calculate the line of best fit for predicted vs. actual
slope, intercept, _, _, _ = linregress(y_pred, y_true)  # Predicted (x) vs. Actual (y)
line_x = np.linspace(y_pred.min(), y_pred.max(), 100)  # Restrict line_x to the range of predicted values
line_y = slope * line_x + intercept  # Compute corresponding y values using the regression equation

# Plot the scatter plot and line of best fit
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, y_true, label="Predicted vs. Actual")  # Predicted on x, Actual on y
plt.plot(line_x, line_y, color="red", label="Line of Best Fit")  # Best-fit line for predicted vs. actual
plt.xlabel("CLIP-CBA Complexity Score (Predicted)")
plt.ylabel("Normalized Participant Complexity Rating (Actual)")
plt.title(f"CLIP-CBA Optimization vs. Participant Ratings: Spearman Rho = {best_rho:.4f}")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Results will be saved in: ./optimization_results_20241127_114618
# Starting cross-validation...
#
# Processing fold 1/5
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.07824857438285247
# Predictor Disorganized: Initial Spearman rho = 0.09212138159750755
# Predictor Asymmetry: Initial Spearman rho = -0.08010037014611138
# Predictor Chaotic: Initial Spearman rho = 0.5299029214930528
# Predictor Randomness: Initial Spearman rho = 0.08342983754994787
# Predictor Variability: Initial Spearman rho = -0.20313595229441173
# Predictor Multicolored: Initial Spearman rho = 0.34126510946063626
# Predictor Heterogeneity: Initial Spearman rho = -0.1239417060276739
# Predictor Grainy: Initial Spearman rho = -0.1822182217480488
# Predictor Isotropy: Initial Spearman rho = -0.2395300825423728
# Predictor Cluttered: Initial Spearman rho = 0.0855137010036818
# Predictor Ambiguity: Initial Spearman rho = -0.4025169006564403
# Predictor Intricate: Initial Spearman rho = 0.4787951934545167
#
# Initial weights set to predictor Chaotic with weight 1. Initial Spearman rho = 0.5299029214930528
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.5820998015758432
# Updated best overall rho to 0.5820998015758432
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.6074356769942425
# Updated best overall rho to 0.6074356769942425
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.6077803774015669
# Updated best overall rho to 0.6077803774015669
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.5569974175760815
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.6073624340898867
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.6077227955069978
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.6073113380680575
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.6075897560198202
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.6077080836493194
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.609467811658075
# Updated best overall rho to 0.609467811658075
# Final weights saved to ./optimization_results_20241127_114618/final_weights_complexity_prediction_fold1.csv
# Fold 1: Test Spearman rho = 0.6084332435142127
#
# Processing fold 2/5
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.046476696651432885
# Predictor Disorganized: Initial Spearman rho = 0.06239616041661187
# Predictor Asymmetry: Initial Spearman rho = -0.10220272957187052
# Predictor Chaotic: Initial Spearman rho = 0.5256352811061127
# Predictor Randomness: Initial Spearman rho = 0.07690911380401633
# Predictor Variability: Initial Spearman rho = -0.19518190863467072
# Predictor Multicolored: Initial Spearman rho = 0.29832605573641824
# Predictor Heterogeneity: Initial Spearman rho = -0.1389488612320863
# Predictor Grainy: Initial Spearman rho = -0.18689629536886052
# Predictor Isotropy: Initial Spearman rho = -0.20359028110115052
# Predictor Cluttered: Initial Spearman rho = 0.013191710031744477
# Predictor Ambiguity: Initial Spearman rho = -0.34796538375355446
# Predictor Intricate: Initial Spearman rho = 0.4569195529725582
#
# Initial weights set to predictor Chaotic with weight 1. Initial Spearman rho = 0.5256352811061127
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.6001298669722174
# Updated best overall rho to 0.6001298669722174
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.600145844651686
# Updated best overall rho to 0.600145844651686
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.5994977203667076
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.6004589122523625
# Updated best overall rho to 0.6004589122523625
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.6002948641968286
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.5999523723547544
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.5974669731257345
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.6004399288708157
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.6006530173286789
# Updated best overall rho to 0.6006530173286789
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.599729317621579
# Final weights saved to ./optimization_results_20241127_114618/final_weights_complexity_prediction_fold2.csv
# Fold 2: Test Spearman rho = 0.6402365664169816
#
# Processing fold 3/5
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.10511007645113603
# Predictor Disorganized: Initial Spearman rho = 0.09998726611918962
# Predictor Asymmetry: Initial Spearman rho = -0.07370753228434011
# Predictor Chaotic: Initial Spearman rho = 0.5214510899068636
# Predictor Randomness: Initial Spearman rho = 0.09701906396811313
# Predictor Variability: Initial Spearman rho = -0.20713979089802106
# Predictor Multicolored: Initial Spearman rho = 0.35108565154552085
# Predictor Heterogeneity: Initial Spearman rho = -0.06453731737768327
# Predictor Grainy: Initial Spearman rho = -0.15254641740002217
# Predictor Isotropy: Initial Spearman rho = -0.18433305765074995
# Predictor Cluttered: Initial Spearman rho = 0.04662258878424627
# Predictor Ambiguity: Initial Spearman rho = -0.3663273688003265
# Predictor Intricate: Initial Spearman rho = 0.48884816638056394
#
# Initial weights set to predictor Chaotic with weight 1. Initial Spearman rho = 0.5214510899068636
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.6287317521766278
# Updated best overall rho to 0.6287317521766278
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.6282546377659447
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.6283187065114112
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.6283130115118141
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.6258540372413706
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.6278120097417103
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.6289407270229516
# Updated best overall rho to 0.6289407270229516
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.6285474556618911
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.6273535622741507
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.629450271292451
# Updated best overall rho to 0.629450271292451
# Final weights saved to ./optimization_results_20241127_114618/final_weights_complexity_prediction_fold3.csv
# Fold 3: Test Spearman rho = 0.5261846876253893
#
# Processing fold 4/5
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.037570227785549706
# Predictor Disorganized: Initial Spearman rho = 0.04832130178126978
# Predictor Asymmetry: Initial Spearman rho = -0.09572524565516219
# Predictor Chaotic: Initial Spearman rho = 0.5024074546206888
# Predictor Randomness: Initial Spearman rho = 0.008405871206123678
# Predictor Variability: Initial Spearman rho = -0.16331865672804477
# Predictor Multicolored: Initial Spearman rho = 0.31438420232801073
# Predictor Heterogeneity: Initial Spearman rho = -0.10579973062348909
# Predictor Grainy: Initial Spearman rho = -0.17028766608338233
# Predictor Isotropy: Initial Spearman rho = -0.21867936349644776
# Predictor Cluttered: Initial Spearman rho = 0.03890204986215086
# Predictor Ambiguity: Initial Spearman rho = -0.3942599901287074
# Predictor Intricate: Initial Spearman rho = 0.49558477326402767
#
# Initial weights set to predictor Chaotic with weight 1. Initial Spearman rho = 0.5024074546206888
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.5749643114086728
# Updated best overall rho to 0.5749643114086728
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.6299289043298482
# Updated best overall rho to 0.6299289043298482
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.6303254927543688
# Updated best overall rho to 0.6303254927543688
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.6301669839385053
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.5784799799952488
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.6296995253048959
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.630144362420872
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.6293388465622127
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.6293855133293581
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.6297797288674137
# Final weights saved to ./optimization_results_20241127_114618/final_weights_complexity_prediction_fold4.csv
# Fold 4: Test Spearman rho = 0.5141908260131224
#
# Processing fold 5/5
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.08101174842240812
# Predictor Disorganized: Initial Spearman rho = 0.02638111268775068
# Predictor Asymmetry: Initial Spearman rho = -0.09970439440321578
# Predictor Chaotic: Initial Spearman rho = 0.5008578408979093
# Predictor Randomness: Initial Spearman rho = 0.10180107638613466
# Predictor Variability: Initial Spearman rho = -0.21329286060323557
# Predictor Multicolored: Initial Spearman rho = 0.3263778004148722
# Predictor Heterogeneity: Initial Spearman rho = -0.10848233212391784
# Predictor Grainy: Initial Spearman rho = -0.19195349768744863
# Predictor Isotropy: Initial Spearman rho = -0.24773767235521643
# Predictor Cluttered: Initial Spearman rho = 0.019071833147931292
# Predictor Ambiguity: Initial Spearman rho = -0.4099829549356636
# Predictor Intricate: Initial Spearman rho = 0.43647717518473816
#
# Initial weights set to predictor Chaotic with weight 1. Initial Spearman rho = 0.5008578408979093
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.5886895797871651
# Updated best overall rho to 0.5886895797871651
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.5888694445385292
# Updated best overall rho to 0.5888694445385292
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.5887738963328792
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.5871404016780113
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.5876883801289567
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.5888453992947232
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.5871404016780113
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.5891342586051812
# Updated best overall rho to 0.5891342586051812
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.5886282011385026
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.5890039080729701
# Final weights saved to ./optimization_results_20241127_114618/final_weights_complexity_prediction_fold5.csv
# Fold 5: Test Spearman rho = 0.7017028840072819
#
# Cross-validation results:
# Irregularity: Mean weight = 0.0000, SE = 0.0000
# Disorganized: Mean weight = 0.1088, SE = 0.0280
# Asymmetry: Mean weight = 0.1475, SE = 0.0221
# Chaotic: Mean weight = 0.2585, SE = 0.0069
# Randomness: Mean weight = 0.0000, SE = 0.0000
# Variability: Mean weight = 0.0000, SE = 0.0000
# Multicolored: Mean weight = 0.2267, SE = 0.0159
# Heterogeneity: Mean weight = 0.0000, SE = 0.0000
# Grainy: Mean weight = 0.0000, SE = 0.0000
# Isotropy: Mean weight = 0.0000, SE = 0.0000
# Cluttered: Mean weight = 0.0000, SE = 0.0000
# Ambiguity: Mean weight = 0.0000, SE = 0.0000
# Intricate: Mean weight = 0.2585, SE = 0.0069
# Mean Spearman rho = 0.5981, SE = 0.0352
# Mean weights and SE saved to ./optimization_results_20241127_114618/mean_weights_complexity_prediction.csv
# Bar plot saved to ./optimization_results_20241127_114618/weights_bar_plot_complexity_prediction.png
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 8
#       5 df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Art/savoias_art_cba_embedding.csv')
#       7 # Run the bayesian optimization function (make sure it's defined in this notebook or imported)
# ----> 8 best_weights, best_rho = optimization.bayesian_optimization_fit(df1, df2, predictor_columns, task_name=task_name, cross_validate=True)
#       9 all_weights.append(best_weights)
#      10 spearman_rhos.append(best_rho)
#
# ValueError: too many values to unpack (expected 2)

# %%
# Run the simulation multiple times
for _ in range(num_simulations):
    # Load your data (ensure these paths are correct)
    df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_interior_design.csv')
    df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Interior_Design/savoias_interior_design_cba_embedding.csv')
    
    # Run the bayesian optimization function (make sure it's defined in this notebook or imported)
    best_weights, best_rho = optimization.bayesian_optimization_fit(df1, df2, predictor_columns, task_name=task_name, cross_validate=False)
    all_weights.append(best_weights)
    spearman_rhos.append(best_rho)

# Find the best (highest) Spearman rho and corresponding weights
best_rho_index = np.argmax(spearman_rhos)
best_rho = spearman_rhos[best_rho_index]
best_weights = all_weights[best_rho_index]

# Calculate predictions for each image using the best weights
# Assuming `df2` contains predictor columns and `df1` contains the actual values
df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_interior_design.csv')
df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Interior_Design/savoias_interior_design_cba_embedding.csv')

# Ensure that df1 and df2 are aligned by merging on 'image' column if necessary
if 'image' in df1.columns and 'image' in df2.columns:
    combined_df = pd.merge(df1, df2, on='image')
    y_true = combined_df['Normalized Average'].values
    X = combined_df[predictor_columns].values
else:
    y_true = df1['Normalized Average'].values
    X = df2[predictor_columns].values

# Get predicted values by multiplying X by best weights
y_pred = X @ best_weights

# Calculate the line of best fit for predicted vs. actual
slope, intercept, _, _, _ = linregress(y_pred, y_true)  # Predicted (x) vs. Actual (y)
line_x = np.linspace(y_pred.min(), y_pred.max(), 100)  # Restrict line_x to the range of predicted values
line_y = slope * line_x + intercept  # Compute corresponding y values using the regression equation

# Plot the scatter plot and line of best fit
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, y_true, label="Predicted vs. Actual")  # Predicted on x, Actual on y
plt.plot(line_x, line_y, color="red", label="Line of Best Fit")  # Best-fit line for predicted vs. actual
plt.xlabel("CLIP-CBA Complexity Score (Predicted)")
plt.ylabel("Normalized Participant Complexity Rating (Actual)")
plt.title(f"CLIP-CBA Optimization vs. Participant Ratings: Spearman Rho = {best_rho:.4f}")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Results will be saved in: ./optimization_results_20241120_164954
# Starting optimization without cross-validation...
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.3341495990708123
# Predictor Disorganized: Initial Spearman rho = 0.0459925347142227
# Predictor Asymmetry: Initial Spearman rho = -0.3406256456526532
# Predictor Chaotic: Initial Spearman rho = 0.4840109587575442
# Predictor Randomness: Initial Spearman rho = 0.34752182500625384
# Predictor Variability: Initial Spearman rho = -0.46848405189264875
# Predictor Multicolored: Initial Spearman rho = 0.5393244391080958
# Predictor Heterogeneity: Initial Spearman rho = -0.276135265187519
# Predictor Grainy: Initial Spearman rho = -0.44619300740241996
# Predictor Isotropy: Initial Spearman rho = -0.3564346416643017
# Predictor Cluttered: Initial Spearman rho = 0.6276663572157095
# Predictor Ambiguity: Initial Spearman rho = -0.6484269180373846
# Predictor Intricate: Initial Spearman rho = 0.422125401477321
#
# Initial weights set to predictor Cluttered with weight 1. Initial Spearman rho = 0.6276663572157095
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.7565570896948864
# Updated best overall rho to 0.7565570896948864
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.7565570896948864
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.7867286246039817
# Updated best overall rho to 0.7867286246039817
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.7869146834029039
# Updated best overall rho to 0.7869146834029039
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.7584656928580239
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.7603322827439853
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.7584656928580239
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.7599901746298381
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.7767594741197948
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.7584656928580239
# Final weights saved to ./optimization_results_20241120_164954/final_weights_complexity_prediction.csv
#
# Optimization results:
# Irregularity: Weight = 0.0000
# Disorganized: Weight = 0.0000
# Asymmetry: Weight = 0.0000
# Chaotic: Weight = 0.0813
# Randomness: Weight = 0.1837
# Variability: Weight = 0.0000
# Multicolored: Weight = 0.1837
# Heterogeneity: Weight = 0.0000
# Grainy: Weight = 0.1837
# Isotropy: Weight = 0.0000
# Cluttered: Weight = 0.1837
# Ambiguity: Weight = 0.0000
# Intricate: Weight = 0.1837
# Best Spearman rho = 0.7869
# Final weights saved to ./optimization_results_20241120_164954/final_weights_complexity_prediction.csv

# %%
# Run the simulation multiple times
for _ in range(num_simulations):
    # Load your data (ensure these paths are correct)
    df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_objects.csv')
    df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Objects/savoias_objects_cba_embedding.csv')
    
    # Run the bayesian optimization function (make sure it's defined in this notebook or imported)
    best_weights, best_rho = optimization.bayesian_optimization_fit(df1, df2, predictor_columns, task_name=task_name, cross_validate=False)
    all_weights.append(best_weights)
    spearman_rhos.append(best_rho)

# Find the best (highest) Spearman rho and corresponding weights
best_rho_index = np.argmax(spearman_rhos)
best_rho = spearman_rhos[best_rho_index]
best_weights = all_weights[best_rho_index]

# Calculate predictions for each image using the best weights
# Assuming `df2` contains predictor columns and `df1` contains the actual values
df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_objects.csv')
df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Objects/savoias_objects_cba_embedding.csv')

# Ensure that df1 and df2 are aligned by merging on 'image' column if necessary
if 'image' in df1.columns and 'image' in df2.columns:
    combined_df = pd.merge(df1, df2, on='image')
    y_true = combined_df['Normalized Average'].values
    X = combined_df[predictor_columns].values
else:
    y_true = df1['Normalized Average'].values
    X = df2[predictor_columns].values

# Get predicted values by multiplying X by best weights
y_pred = X @ best_weights

# Calculate the line of best fit for predicted vs. actual
slope, intercept, _, _, _ = linregress(y_pred, y_true)  # Predicted (x) vs. Actual (y)
line_x = np.linspace(y_pred.min(), y_pred.max(), 100)  # Restrict line_x to the range of predicted values
line_y = slope * line_x + intercept  # Compute corresponding y values using the regression equation

# Plot the scatter plot and line of best fit
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, y_true, label="Predicted vs. Actual")  # Predicted on x, Actual on y
plt.plot(line_x, line_y, color="red", label="Line of Best Fit")  # Best-fit line for predicted vs. actual
plt.xlabel("CLIP-CBA Complexity Score (Predicted)")
plt.ylabel("Normalized Participant Complexity Rating (Actual)")
plt.title(f"CLIP-CBA Optimization vs. Participant Ratings: Spearman Rho = {best_rho:.4f}")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Results will be saved in: ./optimization_results_20241120_165257
# Starting optimization without cross-validation...
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.013612275420466748
# Predictor Disorganized: Initial Spearman rho = -0.07601074790750767
# Predictor Asymmetry: Initial Spearman rho = -0.04877269431348432
# Predictor Chaotic: Initial Spearman rho = 0.2640868449312683
# Predictor Randomness: Initial Spearman rho = -0.009184872712895122
# Predictor Variability: Initial Spearman rho = -0.13077866459288498
# Predictor Multicolored: Initial Spearman rho = 0.04288624411925956
# Predictor Heterogeneity: Initial Spearman rho = -0.12295606963616575
# Predictor Grainy: Initial Spearman rho = -0.16166546213296532
# Predictor Isotropy: Initial Spearman rho = -0.10079430105097621
# Predictor Cluttered: Initial Spearman rho = 0.19490698978132545
# Predictor Ambiguity: Initial Spearman rho = -0.3395687350094236
# Predictor Intricate: Initial Spearman rho = 0.0627412923849332
#
# Initial weights set to predictor Chaotic with weight 1. Initial Spearman rho = 0.2640868449312683
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.30149472206079636
# Updated best overall rho to 0.30149472206079636
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.29823305703664843
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.3024564181419734
# Updated best overall rho to 0.3024564181419734
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.29942429992035285
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.300384495695631
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.2993725393668418
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.29935678615490363
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.2983530815085581
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.29887143719661846
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.29927351917751616
# Final weights saved to ./optimization_results_20241120_165257/final_weights_complexity_prediction.csv
#
# Optimization results:
# Irregularity: Weight = 0.0000
# Disorganized: Weight = 0.0856
# Asymmetry: Weight = 0.0000
# Chaotic: Weight = 0.3338
# Randomness: Weight = 0.0000
# Variability: Weight = 0.0000
# Multicolored: Weight = 0.0000
# Heterogeneity: Weight = 0.0000
# Grainy: Weight = 0.0000
# Isotropy: Weight = 0.0000
# Cluttered: Weight = 0.3338
# Ambiguity: Weight = 0.0000
# Intricate: Weight = 0.2468
# Best Spearman rho = 0.3025
# Final weights saved to ./optimization_results_20241120_165257/final_weights_complexity_prediction.csv

# %%
# Run the simulation multiple times
for _ in range(num_simulations):
    # Load your data (ensure these paths are correct)
    df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_scenes.csv')
    df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Scenes/savoias_scenes_cba_embedding.csv')
    
    # Run the bayesian optimization function (make sure it's defined in this notebook or imported)
    best_weights, best_rho = optimization.bayesian_optimization_fit(df1, df2, predictor_columns, task_name=task_name, cross_validate=True)
    all_weights.append(best_weights)
    spearman_rhos.append(best_rho)

# Find the best (highest) Spearman rho and corresponding weights
best_rho_index = np.argmax(spearman_rhos)
best_rho = spearman_rhos[best_rho_index]
best_weights = all_weights[best_rho_index]

# Calculate predictions for each image using the best weights
# Assuming `df2` contains predictor columns and `df1` contains the actual values
df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_scenes.csv')
df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Scenes/savoias_scenes_cba_embedding.csv')

# Ensure that df1 and df2 are aligned by merging on 'image' column if necessary
if 'image' in df1.columns and 'image' in df2.columns:
    combined_df = pd.merge(df1, df2, on='image')
    y_true = combined_df['Normalized Average'].values
    X = combined_df[predictor_columns].values
else:
    y_true = df1['Normalized Average'].values
    X = df2[predictor_columns].values

# Get predicted values by multiplying X by best weights
y_pred = X @ best_weights

# Calculate the line of best fit for predicted vs. actual
slope, intercept, _, _, _ = linregress(y_pred, y_true)  # Predicted (x) vs. Actual (y)
line_x = np.linspace(y_pred.min(), y_pred.max(), 100)  # Restrict line_x to the range of predicted values
line_y = slope * line_x + intercept  # Compute corresponding y values using the regression equation

# Plot the scatter plot and line of best fit
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, y_true, label="Predicted vs. Actual")  # Predicted on x, Actual on y
plt.plot(line_x, line_y, color="red", label="Line of Best Fit")  # Best-fit line for predicted vs. actual
plt.xlabel("CLIP-CBA Complexity Score (Predicted)")
plt.ylabel("Normalized Participant Complexity Rating (Actual)")
plt.title(f"CLIP-CBA Optimization vs. Participant Ratings: Spearman Rho = {best_rho:.4f}")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Results will be saved in: ./optimization_results_20241127_120533
# Starting cross-validation...
#
# Processing fold 1/5
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.03862663913804742
# Predictor Disorganized: Initial Spearman rho = -0.3039036297511541
# Predictor Asymmetry: Initial Spearman rho = -0.09131131764828963
# Predictor Chaotic: Initial Spearman rho = 0.4245281720857848
# Predictor Randomness: Initial Spearman rho = 0.03434211681948399
# Predictor Variability: Initial Spearman rho = -0.09050247485764429
# Predictor Multicolored: Initial Spearman rho = 0.2930472597585972
# Predictor Heterogeneity: Initial Spearman rho = -0.21010277604977304
# Predictor Grainy: Initial Spearman rho = -0.17003135612988446
# Predictor Isotropy: Initial Spearman rho = -0.2185897641719069
# Predictor Cluttered: Initial Spearman rho = 0.1951904697447046
# Predictor Ambiguity: Initial Spearman rho = -0.37706726993179385
# Predictor Intricate: Initial Spearman rho = 0.36664755782259256
#
# Initial weights set to predictor Chaotic with weight 1. Initial Spearman rho = 0.4245281720857848
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.5306756007037923
# Updated best overall rho to 0.5306756007037923
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.5304074517351544
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.5213607209571753
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.5270812322881163
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.5309862432248371
# Updated best overall rho to 0.5309862432248371
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.5303678887725684
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.5303810764267637
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.5316280423956754
# Updated best overall rho to 0.5316280423956754
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.5227146534545599
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.5293289946809606
# Final weights saved to ./optimization_results_20241127_120533/final_weights_complexity_prediction_fold1.csv
# Fold 1: Test Spearman rho = 0.5421788710649519
#
# Processing fold 2/5
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.08357192248616004
# Predictor Disorganized: Initial Spearman rho = -0.3298158294430752
# Predictor Asymmetry: Initial Spearman rho = -0.08439684301773968
# Predictor Chaotic: Initial Spearman rho = 0.4197863806351114
# Predictor Randomness: Initial Spearman rho = -0.09477501730757736
# Predictor Variability: Initial Spearman rho = 0.03488109800139429
# Predictor Multicolored: Initial Spearman rho = 0.34653109307408864
# Predictor Heterogeneity: Initial Spearman rho = -0.16254597529541615
# Predictor Grainy: Initial Spearman rho = -0.26463685088749994
# Predictor Isotropy: Initial Spearman rho = -0.17113657756300307
# Predictor Cluttered: Initial Spearman rho = 0.18012425525520473
# Predictor Ambiguity: Initial Spearman rho = -0.41461121310839866
# Predictor Intricate: Initial Spearman rho = 0.4048586890263487
#
# Initial weights set to predictor Chaotic with weight 1. Initial Spearman rho = 0.4197863806351114
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.5628932428000353
# Updated best overall rho to 0.5628932428000353
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.5634544231971845
# Updated best overall rho to 0.5634544231971845
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.5648463850177896
# Updated best overall rho to 0.5648463850177896
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.5650295378889217
# Updated best overall rho to 0.5650295378889217
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.564630997241338
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.5662339511694875
# Updated best overall rho to 0.5662339511694875
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.5645987623360188
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.5663746125745172
# Updated best overall rho to 0.5663746125745172
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.5654178219757222
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.5643555353231552
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 8
#       5 df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Scenes/savoias_scenes_cba_embedding.csv')
#       7 # Run the bayesian optimization function (make sure it's defined in this notebook or imported)
# ----> 8 best_weights, best_rho = optimization.bayesian_optimization_fit(df1, df2, predictor_columns, task_name=task_name, cross_validate=True)
#       9 all_weights.append(best_weights)
#      10 spearman_rhos.append(best_rho)
#
# File ~/complexity-final/Optimizations/optimization.py:45, in bayesian_optimization_fit(df1, df2, predictor_columns, task_name, n_calls, tol, n_iter_no_change, n_repeats, cross_validate, n_splits)
#      43 X_train, X_test = X[train_index], X[test_index]
#      44 y_train, y_test = y_true[train_index], y_true[test_index]
# ---> 45 best_theta, best_rho = optimize_weights(X_train, y_train, predictor_columns,
#      46                                         task_name + f"_fold{fold}", n_calls, tol,
#      47                                         n_iter_no_change, n_repeats, opt_dir)
#      48 # Evaluate on the test set
#      49 y_pred = X_test @ best_theta
#
# File ~/complexity-final/Optimizations/optimization.py:182, in optimize_weights(X, y_true, predictor_columns, task_name, n_calls, tol, n_iter_no_change, n_repeats, opt_dir)
#     177 final_weights_df = pd.DataFrame({
#     178     'Predictor': predictor_columns,
#     179     'Weight': best_overall_theta
#     180 })
#     181 final_weights_csv_path = os.path.join(opt_dir, f'final_weights_{task_name}.csv')
# --> 182 final_weights_df.to_csv(final_weights_csv_path, index=False)
#     183 print(f"Final weights saved to {final_weights_csv_path}")
#     185 with open(filename, 'a') as f:
#
# File ~/miniconda/envs/complexity_experiment/lib/python3.8/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~/miniconda/envs/complexity_experiment/lib/python3.8/site-packages/pandas/io/formats/format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~/miniconda/envs/complexity_experiment/lib/python3.8/site-packages/pandas/io/formats/csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~/miniconda/envs/complexity_experiment/lib/python3.8/site-packages/pandas/io/common.py:737, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735 # Only for write methods
#     736 if "r" not in mode and is_path:
# --> 737     check_parent_directory(str(handle))
#     739 if compression:
#     740     if compression != "zstd":
#     741         # compression libraries do not like an explicit text-mode
#
# File ~/miniconda/envs/complexity_experiment/lib/python3.8/site-packages/pandas/io/common.py:600, in check_parent_directory(path)
#     598 parent = Path(path).parent
#     599 if not parent.is_dir():
# --> 600     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'optimization_results_20241127_120533'

# %%
# Run the simulation multiple times
for _ in range(num_simulations):
    # Load your data (ensure these paths are correct)
    df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_sup.csv')
    df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Suprematism/savoias_suprematism_cba_embedding.csv')
    
    # Run the bayesian optimization function (make sure it's defined in this notebook or imported)
    best_weights, best_rho = optimization.bayesian_optimization_fit(df1, df2, predictor_columns, task_name=task_name, cross_validate=False)
    all_weights.append(best_weights)
    spearman_rhos.append(best_rho)

# Find the best (highest) Spearman rho and corresponding weights
best_rho_index = np.argmax(spearman_rhos)
best_rho = spearman_rhos[best_rho_index]
best_weights = all_weights[best_rho_index]

# Calculate predictions for each image using the best weights
# Assuming `df2` contains predictor columns and `df1` contains the actual values
df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_sup.csv')
df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Suprematism/savoias_suprematism_cba_embedding.csv')

# Ensure that df1 and df2 are aligned by merging on 'image' column if necessary
if 'image' in df1.columns and 'image' in df2.columns:
    combined_df = pd.merge(df1, df2, on='image')
    y_true = combined_df['Normalized Average'].values
    X = combined_df[predictor_columns].values
else:
    y_true = df1['Normalized Average'].values
    X = df2[predictor_columns].values

# Get predicted values by multiplying X by best weights
y_pred = X @ best_weights

# Calculate the line of best fit for predicted vs. actual
slope, intercept, _, _, _ = linregress(y_pred, y_true)  # Predicted (x) vs. Actual (y)
line_x = np.linspace(y_pred.min(), y_pred.max(), 100)  # Restrict line_x to the range of predicted values
line_y = slope * line_x + intercept  # Compute corresponding y values using the regression equation

# Plot the scatter plot and line of best fit
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, y_true, label="Predicted vs. Actual")  # Predicted on x, Actual on y
plt.plot(line_x, line_y, color="red", label="Line of Best Fit")  # Best-fit line for predicted vs. actual
plt.xlabel("CLIP-CBA Complexity Score (Predicted)")
plt.ylabel("Normalized Participant Complexity Rating (Actual)")
plt.title(f"CLIP-CBA Optimization vs. Participant Ratings: Spearman Rho = {best_rho:.4f}")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Results will be saved in: ./optimization_results_20241120_170248
# Starting optimization without cross-validation...
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.24841548673858418
# Predictor Disorganized: Initial Spearman rho = 0.28076009661159945
# Predictor Asymmetry: Initial Spearman rho = 0.16772501816689783
# Predictor Chaotic: Initial Spearman rho = 0.506686206249759
# Predictor Randomness: Initial Spearman rho = -0.0024968190215576853
# Predictor Variability: Initial Spearman rho = -0.44999160894775453
# Predictor Multicolored: Initial Spearman rho = 0.5570067126842293
# Predictor Heterogeneity: Initial Spearman rho = -0.3425383614887467
# Predictor Grainy: Initial Spearman rho = -0.3708076345453253
# Predictor Isotropy: Initial Spearman rho = 0.017831849310211256
# Predictor Cluttered: Initial Spearman rho = -0.13440808934798748
# Predictor Ambiguity: Initial Spearman rho = -0.18919406057101285
# Predictor Intricate: Initial Spearman rho = 0.4280304051018901
#
# Initial weights set to predictor Multicolored with weight 1. Initial Spearman rho = 0.5570067126842293
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.6814515338211933
# Updated best overall rho to 0.6814515338211933
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.6805692444073256
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.6807433015025786
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.678168456886597
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.6813434983827605
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.6817816421052935
# Updated best overall rho to 0.6817816421052935
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.6811034196306877
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.6810073881298586
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.6805692444073256
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.6796749510558542
# Final weights saved to ./optimization_results_20241120_170248/final_weights_complexity_prediction.csv
#
# Optimization results:
# Irregularity: Weight = 0.0000
# Disorganized: Weight = 0.1769
# Asymmetry: Weight = 0.1769
# Chaotic: Weight = 0.1769
# Randomness: Weight = 0.0000
# Variability: Weight = 0.0000
# Multicolored: Weight = 0.1769
# Heterogeneity: Weight = 0.0000
# Grainy: Weight = 0.0000
# Isotropy: Weight = 0.1156
# Cluttered: Weight = 0.0000
# Ambiguity: Weight = 0.0000
# Intricate: Weight = 0.1769
# Best Spearman rho = 0.6818
# Final weights saved to ./optimization_results_20241120_170248/final_weights_complexity_prediction.csv

# %%
# Run the simulation multiple times
for _ in range(num_simulations):
    # Load your data (ensure these paths are correct)
    df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_vis.csv')
    df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Visualizations/savoias_visualizations_cba_embedding.csv')
    
    # Run the bayesian optimization function (make sure it's defined in this notebook or imported)
    best_weights, best_rho = optimization.bayesian_optimization_fit(df1, df2, predictor_columns, task_name=task_name, cross_validate=False)
    all_weights.append(best_weights)
    spearman_rhos.append(best_rho)

# Find the best (highest) Spearman rho and corresponding weights
best_rho_index = np.argmax(spearman_rhos)
best_rho = spearman_rhos[best_rho_index]
best_weights = all_weights[best_rho_index]

# Calculate predictions for each image using the best weights
# Assuming `df2` contains predictor columns and `df1` contains the actual values
df1 = pd.read_csv('/home/wallacelab/complexity-final/Savoias-Dataset/Ground truth/csv/global_ranking_vis.csv')
df2 = pd.read_csv('/home/wallacelab/complexity-final/Embeddings/CLIP-CBA/Savoias/Visualizations/savoias_visualizations_cba_embedding.csv')

# Ensure that df1 and df2 are aligned by merging on 'image' column if necessary
if 'image' in df1.columns and 'image' in df2.columns:
    combined_df = pd.merge(df1, df2, on='image')
    y_true = combined_df['Normalized Average'].values
    X = combined_df[predictor_columns].values
else:
    y_true = df1['Normalized Average'].values
    X = df2[predictor_columns].values

# Get predicted values by multiplying X by best weights
y_pred = X @ best_weights

# Calculate the line of best fit for predicted vs. actual
slope, intercept, _, _, _ = linregress(y_pred, y_true)  # Predicted (x) vs. Actual (y)
line_x = np.linspace(y_pred.min(), y_pred.max(), 100)  # Restrict line_x to the range of predicted values
line_y = slope * line_x + intercept  # Compute corresponding y values using the regression equation

# Plot the scatter plot and line of best fit
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, y_true, label="Predicted vs. Actual")  # Predicted on x, Actual on y
plt.plot(line_x, line_y, color="red", label="Line of Best Fit")  # Best-fit line for predicted vs. actual
plt.xlabel("CLIP-CBA Complexity Score (Predicted)")
plt.ylabel("Normalized Participant Complexity Rating (Actual)")
plt.title(f"CLIP-CBA Optimization vs. Participant Ratings: Spearman Rho = {best_rho:.4f}")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Results will be saved in: ./optimization_results_20241120_170649
# Starting optimization without cross-validation...
# Calculating initial Spearman correlations for each predictor...
# Predictor Irregularity: Initial Spearman rho = -0.2443490880075415
# Predictor Disorganized: Initial Spearman rho = -0.054059001670867836
# Predictor Asymmetry: Initial Spearman rho = -0.10747888213971557
# Predictor Chaotic: Initial Spearman rho = 0.1775586719696721
# Predictor Randomness: Initial Spearman rho = 0.011450921536193679
# Predictor Variability: Initial Spearman rho = -0.061326379845951
# Predictor Multicolored: Initial Spearman rho = 0.03892863236952316
# Predictor Heterogeneity: Initial Spearman rho = -0.15138770894610673
# Predictor Grainy: Initial Spearman rho = -0.10057832352776366
# Predictor Isotropy: Initial Spearman rho = -0.2642713660395252
# Predictor Cluttered: Initial Spearman rho = 0.11833044001345142
# Predictor Ambiguity: Initial Spearman rho = -0.17328361125334268
# Predictor Intricate: Initial Spearman rho = 0.14297636383078804
#
# Initial weights set to predictor Chaotic with weight 1. Initial Spearman rho = 0.1775586719696721
#
# Starting repeat 1/10...
# Repeat 1 best rho: 0.21618724743683834
# Updated best overall rho to 0.21618724743683834
#
# Starting repeat 2/10...
# Repeat 2 best rho: 0.21608297766326937
#
# Starting repeat 3/10...
# Repeat 3 best rho: 0.2160192155715185
#
# Starting repeat 4/10...
# Repeat 4 best rho: 0.213442476922529
#
# Starting repeat 5/10...
# Repeat 5 best rho: 0.20575351879963444
#
# Starting repeat 6/10...
# Repeat 6 best rho: 0.20492086089559416
#
# Starting repeat 7/10...
# Repeat 7 best rho: 0.20701000707825382
#
# Starting repeat 8/10...
# Repeat 8 best rho: 0.2160874785168047
#
# Starting repeat 9/10...
# Repeat 9 best rho: 0.20559748921040888
#
# Starting repeat 10/10...
# Repeat 10 best rho: 0.21633202489222556
# Updated best overall rho to 0.21633202489222556
# Final weights saved to ./optimization_results_20241120_170649/final_weights_complexity_prediction.csv
#
# Optimization results:
# Irregularity: Weight = 0.0000
# Disorganized: Weight = 0.0000
# Asymmetry: Weight = 0.0000
# Chaotic: Weight = 0.5309
# Randomness: Weight = 0.0000
# Variability: Weight = 0.0000
# Multicolored: Weight = 0.0000
# Heterogeneity: Weight = 0.0000
# Grainy: Weight = 0.0000
# Isotropy: Weight = 0.0000
# Cluttered: Weight = 0.2380
# Ambiguity: Weight = 0.0000
# Intricate: Weight = 0.2311
# Best Spearman rho = 0.2163
# Final weights saved to ./optimization_results_20241120_170649/final_weights_complexity_prediction.csv
